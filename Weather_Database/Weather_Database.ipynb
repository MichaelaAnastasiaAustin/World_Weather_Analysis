# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=932eea3c9418d5072ded84bddf4da0c9

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayacucho
# Processing Record 2 of Set 1 | koregaon
# Processing Record 3 of Set 1 | broome
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | muli
# Processing Record 9 of Set 1 | vega de alatorre
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | shenyang
# Processing Record 14 of Set 1 | minchinabad
# Processing Record 15 of Set 1 | mangrol
# Processing Record 16 of Set 1 | ulladulla
# Processing Record 17 of Set 1 | zhanaozen
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | aksarka
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | henties bay
# Processing Record 23 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | yichang
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | gorontalo
# Processing Record 32 of Set 1 | udachnyy
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | rezekne
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | potam
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | bubaque
# Processing Record 48 of Set 1 | carndonagh
# Processing Record 49 of Set 1 | beloha
# Processing Record 50 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 1 of Set 2 | matsumoto
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | egvekinot
# Processing Record 4 of Set 2 | hastings
# Processing Record 5 of Set 2 | vavuniya
# Processing Record 6 of Set 2 | mayumba
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | entre rios
# Processing Record 9 of Set 2 | college
# Processing Record 10 of Set 2 | mandalgovi
# Processing Record 11 of Set 2 | wuwei
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | salalah
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | thio
# Processing Record 20 of Set 2 | chegdomyn
# Processing Record 21 of Set 2 | pacific grove
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | butler
# Processing Record 24 of Set 2 | chapada dos guimaraes
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | la ronge
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | unguia
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | upata
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | sydney mines
# Processing Record 35 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 2 | shenjiamen
# Processing Record 37 of Set 2 | cap malheureux
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | meulaboh
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | yarkovo
# Processing Record 44 of Set 2 | melfi
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | serrinha
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | dunda
# Processing Record 2 of Set 3 | ambilobe
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | vila velha
# Processing Record 5 of Set 3 | juneau
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | porbandar
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | vista hermosa
# Processing Record 11 of Set 3 | lofthus
# Processing Record 12 of Set 3 | shunyi
# Processing Record 13 of Set 3 | mabaruma
# Processing Record 14 of Set 3 | sobolevo
# Processing Record 15 of Set 3 | hamada
# Processing Record 16 of Set 3 | sabha
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | jawhar
# Processing Record 21 of Set 3 | roald
# Processing Record 22 of Set 3 | hami
# Processing Record 23 of Set 3 | pietarsaari
# Processing Record 24 of Set 3 | kenai
# Processing Record 25 of Set 3 | diamantina
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | verkhnyaya inta
# Processing Record 28 of Set 3 | saint-pierre
# Processing Record 29 of Set 3 | biak
# Processing Record 30 of Set 3 | marzuq
# Processing Record 31 of Set 3 | zyryanka
# Processing Record 32 of Set 3 | san cristobal
# Processing Record 33 of Set 3 | loiza
# Processing Record 34 of Set 3 | touros
# Processing Record 35 of Set 3 | sabang
# Processing Record 36 of Set 3 | tessalit
# Processing Record 37 of Set 3 | bandipur
# Processing Record 38 of Set 3 | vestmannaeyjar
# Processing Record 39 of Set 3 | blumenau
# Processing Record 40 of Set 3 | beira
# Processing Record 41 of Set 3 | samana
# Processing Record 42 of Set 3 | porirua
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | thinadhoo
# Processing Record 45 of Set 3 | lazaro cardenas
# Processing Record 46 of Set 3 | san vicente de canete
# Processing Record 47 of Set 3 | sinop
# Processing Record 48 of Set 3 | surt
# Processing Record 49 of Set 3 | san giorgio del sannio
# Processing Record 50 of Set 3 | byron bay
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | saint-augustin
# Processing Record 4 of Set 4 | kulhudhuffushi
# Processing Record 5 of Set 4 | fairbanks
# Processing Record 6 of Set 4 | kurush
# Processing Record 7 of Set 4 | cangzhou
# Processing Record 8 of Set 4 | beaupre
# Processing Record 9 of Set 4 | la paz
# Processing Record 10 of Set 4 | djibo
# Processing Record 11 of Set 4 | saint-leu
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | baiyin
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | pontes e lacerda
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | shahr-e babak
# Processing Record 20 of Set 4 | matane
# Processing Record 21 of Set 4 | brussels
# Processing Record 22 of Set 4 | strezhevoy
# Processing Record 23 of Set 4 | chumikan
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 4 | mukhen
# Processing Record 27 of Set 4 | shingu
# Processing Record 28 of Set 4 | papetoai
# Processing Record 29 of Set 4 | sao joao da barra
# Processing Record 30 of Set 4 | pokhara
# Processing Record 31 of Set 4 | chiche
# Processing Record 32 of Set 4 | acajutla
# Processing Record 33 of Set 4 | loikaw
# Processing Record 34 of Set 4 | flinders
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | tongliao
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | effingham
# Processing Record 39 of Set 4 | wenling
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | bilibino
# Processing Record 43 of Set 4 | riyadh
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | birsk
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | la fleche
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | karwar
# Processing Record 1 of Set 5 | pucallpa
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | jutai
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | champerico
# Processing Record 9 of Set 5 | ardakan
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | praia da vitoria
# Processing Record 12 of Set 5 | tilichiki
# Processing Record 13 of Set 5 | yumen
# Processing Record 14 of Set 5 | kedrovka
# Processing Record 15 of Set 5 | veraval
# Processing Record 16 of Set 5 | ouadda
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | sao felix do xingu
# Processing Record 19 of Set 5 | manta
# Processing Record 20 of Set 5 | orchard homes
# Processing Record 21 of Set 5 | buraydah
# Processing Record 22 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 23 of Set 5 | newport
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | teofilo otoni
# Processing Record 26 of Set 5 | castro
# Processing Record 27 of Set 5 | baruun-urt
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | mae chan
# Processing Record 30 of Set 5 | kutum
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | aguimes
# Processing Record 33 of Set 5 | colares
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | kloulklubed
# Processing Record 36 of Set 5 | deputatskiy
# Processing Record 37 of Set 5 | meadow lake
# Processing Record 38 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 5 | idil
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | ouallam
# Processing Record 42 of Set 5 | krasnokholmskiy
# Processing Record 43 of Set 5 | grand forks
# Processing Record 44 of Set 5 | slavuta
# Processing Record 45 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 5 | lahaina
# Processing Record 47 of Set 5 | sao filipe
# Processing Record 48 of Set 5 | ranong
# Processing Record 49 of Set 5 | jumla
# Processing Record 50 of Set 5 | havre-saint-pierre
# Processing Record 1 of Set 6 | mitsamiouli
# Processing Record 2 of Set 6 | barreirinha
# Processing Record 3 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 4 of Set 6 | berdigestyakh
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | mount pleasant
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | ploemeur
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | ulcinj
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | shimoda
# Processing Record 14 of Set 6 | avera
# Processing Record 15 of Set 6 | alexandria
# Processing Record 16 of Set 6 | fare
# Processing Record 17 of Set 6 | puerto maldonado
# Processing Record 18 of Set 6 | seoul
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | hualmay
# Processing Record 21 of Set 6 | grandview
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | tumut
# Processing Record 24 of Set 6 | miri
# Processing Record 25 of Set 6 | gubkinskiy
# Processing Record 26 of Set 6 | nikolskoye
# Processing Record 27 of Set 6 | ixtapa
# Processing Record 28 of Set 6 | awjilah
# Processing Record 29 of Set 6 | petrokamenskoye
# Processing Record 30 of Set 6 | tautira
# Processing Record 31 of Set 6 | pervomayskiy
# Processing Record 32 of Set 6 | aneho
# Processing Record 33 of Set 6 | lata
# Processing Record 34 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 35 of Set 6 | sorata
# Processing Record 36 of Set 6 | quatre cocos
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | belyy yar
# Processing Record 39 of Set 6 | chalus
# Processing Record 40 of Set 6 | saint-philippe
# Processing Record 41 of Set 6 | labuan
# Processing Record 42 of Set 6 | chuy
# Processing Record 43 of Set 6 | binabalian
# Processing Record 44 of Set 6 | geraldton
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | santa vitoria do palmar
# Processing Record 47 of Set 6 | balikpapan
# Processing Record 48 of Set 6 | aitape
# Processing Record 49 of Set 6 | poum
# Processing Record 50 of Set 6 | jalu
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 2 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 7 | ponca city
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | novoukrainskoye
# Processing Record 6 of Set 7 | bathsheba
# Processing Record 7 of Set 7 | le port
# Processing Record 8 of Set 7 | calvia
# Processing Record 9 of Set 7 | casablanca
# Processing Record 10 of Set 7 | los llanos de aridane
# Processing Record 11 of Set 7 | bintulu
# Processing Record 12 of Set 7 | altamira
# Processing Record 13 of Set 7 | sokoni
# Processing Record 14 of Set 7 | mayor pablo lagerenza
# Processing Record 15 of Set 7 | shiyan
# Processing Record 16 of Set 7 | khasan
# Processing Record 17 of Set 7 | thunder bay
# Processing Record 18 of Set 7 | hofn
# Processing Record 19 of Set 7 | manggar
# Processing Record 20 of Set 7 | yangambi
# Processing Record 21 of Set 7 | urucui
# Processing Record 22 of Set 7 | fazalpur
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | kieta
# Processing Record 25 of Set 7 | hobyo
# Processing Record 26 of Set 7 | bandarbeyla
# Processing Record 27 of Set 7 | pirae
# Processing Record 28 of Set 7 | tatvan
# Processing Record 29 of Set 7 | merauke
# Processing Record 30 of Set 7 | tangping
# Processing Record 31 of Set 7 | hovd
# Processing Record 32 of Set 7 | oskarshamn
# Processing Record 33 of Set 7 | caarapo
# Processing Record 34 of Set 7 | ishigaki
# Processing Record 35 of Set 7 | cerrito
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | kayerkan
# Processing Record 38 of Set 7 | mahebourg
# Processing Record 39 of Set 7 | vao
# Processing Record 40 of Set 7 | mount gambier
# Processing Record 41 of Set 7 | teguise
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | lieksa
# Processing Record 44 of Set 7 | northam
# Processing Record 45 of Set 7 | launceston
# Processing Record 46 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 7 | cordoba
# Processing Record 48 of Set 7 | marsa matruh
# Processing Record 49 of Set 7 | bani walid
# Processing Record 50 of Set 7 | ornes
# Processing Record 1 of Set 8 | port blair
# Processing Record 2 of Set 8 | camapua
# Processing Record 3 of Set 8 | tuatapere
# Processing Record 4 of Set 8 | puerto baquerizo moreno
# Processing Record 5 of Set 8 | safaga
# Processing Record 6 of Set 8 | sorrento
# Processing Record 7 of Set 8 | mar del plata
# Processing Record 8 of Set 8 | semey
# Processing Record 9 of Set 8 | rafraf
# Processing Record 10 of Set 8 | inta
# Processing Record 11 of Set 8 | karpogory
# Processing Record 12 of Set 8 | la orilla
# Processing Record 13 of Set 8 | trofors
# Processing Record 14 of Set 8 | dikson
# Processing Record 15 of Set 8 | upernavik
# Processing Record 16 of Set 8 | chokurdakh
# Processing Record 17 of Set 8 | katherine
# Processing Record 18 of Set 8 | astoria
# Processing Record 19 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 20 of Set 8 | anqing
# Processing Record 21 of Set 8 | buchanan
# Processing Record 22 of Set 8 | tuku
# Processing Record 23 of Set 8 | vrangel
# Processing Record 24 of Set 8 | rio grande
# Processing Record 25 of Set 8 | umm lajj
# Processing Record 26 of Set 8 | hervey bay
# Processing Record 27 of Set 8 | along
# Processing Record 28 of Set 8 | seredka
# Processing Record 29 of Set 8 | khonsa
# Processing Record 30 of Set 8 | bulungu
# Processing Record 31 of Set 8 | muzhi
# Processing Record 32 of Set 8 | westport
# Processing Record 33 of Set 8 | pangody
# Processing Record 34 of Set 8 | kuala sungai baru
# Processing Record 35 of Set 8 | brunsbuttel
# Processing Record 36 of Set 8 | oistins
# Processing Record 37 of Set 8 | bairiki
# Processing Record 38 of Set 8 | royan
# Processing Record 39 of Set 8 | tevriz
# Processing Record 40 of Set 8 | morgan city
# Processing Record 41 of Set 8 | suao
# City not found. Skipping...
# Processing Record 42 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | marsh harbour
# Processing Record 45 of Set 8 | mporokoso
# Processing Record 46 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | brus
# Processing Record 49 of Set 8 | san juan
# Processing Record 50 of Set 8 | guatire
# Processing Record 1 of Set 9 | loandjili
# Processing Record 2 of Set 9 | gbadolite
# Processing Record 3 of Set 9 | fort nelson
# Processing Record 4 of Set 9 | faya
# Processing Record 5 of Set 9 | volchikha
# Processing Record 6 of Set 9 | san felipe
# Processing Record 7 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 9 | tombouctou
# Processing Record 9 of Set 9 | kalabo
# Processing Record 10 of Set 9 | kalmar
# Processing Record 11 of Set 9 | balabac
# Processing Record 12 of Set 9 | guerrero negro
# Processing Record 13 of Set 9 | husavik
# Processing Record 14 of Set 9 | katangli
# Processing Record 15 of Set 9 | epernay
# Processing Record 16 of Set 9 | luwuk
# Processing Record 17 of Set 9 | manaus
# Processing Record 18 of Set 9 | aklavik
# Processing Record 19 of Set 9 | almeirim
# Processing Record 20 of Set 9 | sibolga
# Processing Record 21 of Set 9 | jiujiang
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | vilhena
# Processing Record 24 of Set 9 | ulaanbaatar
# Processing Record 25 of Set 9 | umm kaddadah
# Processing Record 26 of Set 9 | laguna
# Processing Record 27 of Set 9 | itoigawa
# Processing Record 28 of Set 9 | sibiti
# Processing Record 29 of Set 9 | malinovoye ozero
# Processing Record 30 of Set 9 | rocha
# Processing Record 31 of Set 9 | mantua
# Processing Record 32 of Set 9 | gigmoto
# Processing Record 33 of Set 9 | ust-kulom
# Processing Record 34 of Set 9 | nuevo ideal
# Processing Record 35 of Set 9 | ponta do sol
# Processing Record 36 of Set 9 | acapulco
# Processing Record 37 of Set 9 | teguldet
# Processing Record 38 of Set 9 | livani
# Processing Record 39 of Set 9 | vestmanna
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | tarpa
# Processing Record 43 of Set 9 | zhezkazgan
# Processing Record 44 of Set 9 | harper
# Processing Record 45 of Set 9 | faanui
# Processing Record 46 of Set 9 | talakan
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | bambanglipuro
# Processing Record 1 of Set 10 | vila franca do campo
# Processing Record 2 of Set 10 | gamboula
# Processing Record 3 of Set 10 | turayf
# Processing Record 4 of Set 10 | tabasco
# Processing Record 5 of Set 10 | mkushi
# Processing Record 6 of Set 10 | conceicao do araguaia
# Processing Record 7 of Set 10 | bulawayo
# Processing Record 8 of Set 10 | tura
# Processing Record 9 of Set 10 | sorong
# Processing Record 10 of Set 10 | cayenne
# Processing Record 11 of Set 10 | wasilla
# Processing Record 12 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 10 | biloela
# Processing Record 14 of Set 10 | pampa
# Processing Record 15 of Set 10 | kathmandu
# Processing Record 16 of Set 10 | erdenet
# Processing Record 17 of Set 10 | saint leonard
# Processing Record 18 of Set 10 | tayga
# Processing Record 19 of Set 10 | alekseyevka
# Processing Record 20 of Set 10 | izhma
# Processing Record 21 of Set 10 | khromtau
# Processing Record 22 of Set 10 | north platte
# Processing Record 23 of Set 10 | inirida
# Processing Record 24 of Set 10 | pochutla
# Processing Record 25 of Set 10 | chifeng
# Processing Record 26 of Set 10 | namatanai
# Processing Record 27 of Set 10 | luanda
# Processing Record 28 of Set 10 | victoria
# Processing Record 29 of Set 10 | lalibela
# Processing Record 30 of Set 10 | morant bay
# Processing Record 31 of Set 10 | santa cruz
# Processing Record 32 of Set 10 | recas
# Processing Record 33 of Set 10 | dingle
# Processing Record 34 of Set 10 | methoni
# Processing Record 35 of Set 10 | urucara
# Processing Record 36 of Set 10 | ballina
# Processing Record 37 of Set 10 | palmer
# Processing Record 38 of Set 10 | salinopolis
# Processing Record 39 of Set 10 | znin
# Processing Record 40 of Set 10 | torit
# Processing Record 41 of Set 10 | fuerte
# Processing Record 42 of Set 10 | magnor
# Processing Record 43 of Set 10 | goulburn
# Processing Record 44 of Set 10 | lakes entrance
# Processing Record 45 of Set 10 | richards bay
# Processing Record 46 of Set 10 | fonte boa
# Processing Record 47 of Set 10 | marabba
# Processing Record 48 of Set 10 | sturgeon falls
# Processing Record 49 of Set 10 | port hedland
# Processing Record 50 of Set 10 | raub
# Processing Record 1 of Set 11 | seydi
# Processing Record 2 of Set 11 | alibag
# Processing Record 3 of Set 11 | innisfail
# Processing Record 4 of Set 11 | mildura
# Processing Record 5 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 11 | yankton
# Processing Record 7 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 11 | nicoya
# Processing Record 9 of Set 11 | mnogovershinnyy
# Processing Record 10 of Set 11 | ajdabiya
# Processing Record 11 of Set 11 | rabo de peixe
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | haines junction
# Processing Record 14 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 11 | kuhdasht
# Processing Record 16 of Set 11 | wattegama
# Processing Record 17 of Set 11 | okakarara
# Processing Record 18 of Set 11 | mocuba
# Processing Record 19 of Set 11 | sindor
# Processing Record 20 of Set 11 | tibu
# Processing Record 21 of Set 11 | arua
# Processing Record 22 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | kavaratti
# Processing Record 25 of Set 11 | coahuayana
# Processing Record 26 of Set 11 | tazovskiy
# Processing Record 27 of Set 11 | litovko
# Processing Record 28 of Set 11 | sulangan
# Processing Record 29 of Set 11 | paoua
# Processing Record 30 of Set 11 | gidam
# Processing Record 31 of Set 11 | cabo san lucas
# Processing Record 32 of Set 11 | poli
# Processing Record 33 of Set 11 | menongue
# Processing Record 34 of Set 11 | sansepolcro
# Processing Record 35 of Set 11 | suluq
# Processing Record 36 of Set 11 | dawlatabad
# Processing Record 37 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 11 | yar-sale
# Processing Record 39 of Set 11 | abriaqui
# Processing Record 40 of Set 11 | bridlington
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | hakui
# Processing Record 43 of Set 11 | ingleside
# Processing Record 44 of Set 11 | bolshoye selo
# Processing Record 45 of Set 11 | russell
# Processing Record 46 of Set 11 | comodoro rivadavia
# Processing Record 47 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | katobu
# Processing Record 50 of Set 11 | port hawkesbury
# Processing Record 1 of Set 12 | kenora
# Processing Record 2 of Set 12 | oussouye
# Processing Record 3 of Set 12 | namtsy
# Processing Record 4 of Set 12 | awbari
# Processing Record 5 of Set 12 | uspantan
# Processing Record 6 of Set 12 | bandarban
# Processing Record 7 of Set 12 | half moon bay
# Processing Record 8 of Set 12 | kilindoni
# Processing Record 9 of Set 12 | wajima
# Processing Record 10 of Set 12 | nyurba
# Processing Record 11 of Set 12 | plouzane
# Processing Record 12 of Set 12 | padrauna
# Processing Record 13 of Set 12 | gariaband
# Processing Record 14 of Set 12 | luang prabang
# Processing Record 15 of Set 12 | alofi
# Processing Record 16 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 12 | weiser
# Processing Record 18 of Set 12 | katha
# City not found. Skipping...
# Processing Record 19 of Set 12 | chimbote
# Processing Record 20 of Set 12 | santiago
# Processing Record 21 of Set 12 | alice springs
# Processing Record 22 of Set 12 | panama city
# Processing Record 23 of Set 12 | zlobin
# Processing Record 24 of Set 12 | mackenzie
# Processing Record 25 of Set 12 | cabra
# Processing Record 26 of Set 12 | blythe
# Processing Record 27 of Set 12 | kalmunai
# Processing Record 28 of Set 12 | kashi
# Processing Record 29 of Set 12 | ponta delgada
# Processing Record 30 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 31 of Set 12 | san jeronimo
# Processing Record 32 of Set 12 | barcelos
# Processing Record 33 of Set 12 | panguna
# Processing Record 34 of Set 12 | maumere
# Processing Record 35 of Set 12 | henzada
# City not found. Skipping...
# Processing Record 36 of Set 12 | aquiraz
# Processing Record 37 of Set 12 | taltal
# Processing Record 38 of Set 12 | vung tau
# Processing Record 39 of Set 12 | minab
# Processing Record 40 of Set 12 | bitung
# Processing Record 41 of Set 12 | natal
# Processing Record 42 of Set 12 | lahat
# Processing Record 43 of Set 12 | maneadero
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | san patricio
# Processing Record 46 of Set 12 | kamenka
# Processing Record 47 of Set 12 | jardim
# Processing Record 48 of Set 12 | bunbury
# Processing Record 49 of Set 12 | mackay
# Processing Record 50 of Set 12 | kannur
# Processing Record 1 of Set 13 | wadi musa
# Processing Record 2 of Set 13 | vaitape
# Processing Record 3 of Set 13 | dingtao
# Processing Record 4 of Set 13 | muravlenko
# Processing Record 5 of Set 13 | coquimbo
# Processing Record 6 of Set 13 | cairns
# Processing Record 7 of Set 13 | oyem
# Processing Record 8 of Set 13 | tommot
# Processing Record 9 of Set 13 | carutapera
# Processing Record 10 of Set 13 | vadamadurai
# Processing Record 11 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 12 of Set 13 | sampit
# Processing Record 13 of Set 13 | srandakan
# Processing Record 14 of Set 13 | palamos
# Processing Record 15 of Set 13 | senneterre
# Processing Record 16 of Set 13 | ibotirama
# Processing Record 17 of Set 13 | the valley
# Processing Record 18 of Set 13 | arman
# Processing Record 19 of Set 13 | vardo
# Processing Record 20 of Set 13 | goderich
# Processing Record 21 of Set 13 | alta floresta
# Processing Record 22 of Set 13 | margate
# Processing Record 23 of Set 13 | oranjemund
# Processing Record 24 of Set 13 | ugoofaaru
# Processing Record 25 of Set 13 | naze
# Processing Record 26 of Set 13 | khakurinokhabl
# Processing Record 27 of Set 13 | galesong
# Processing Record 28 of Set 13 | kedougou
# Processing Record 29 of Set 13 | great yarmouth
# Processing Record 30 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 13 | andenes
# Processing Record 32 of Set 13 | dutlwe
# Processing Record 33 of Set 13 | qasigiannguit
# Processing Record 34 of Set 13 | mahibadhoo
# Processing Record 35 of Set 13 | xuchang
# Processing Record 36 of Set 13 | khurja
# Processing Record 37 of Set 13 | huron
# Processing Record 38 of Set 13 | okhotsk
# Processing Record 39 of Set 13 | adrar
# Processing Record 40 of Set 13 | olinda
# Processing Record 41 of Set 13 | tabou
# Processing Record 42 of Set 13 | sibu
# Processing Record 43 of Set 13 | ust-kuyga
# Processing Record 44 of Set 13 | shawnee
# Processing Record 45 of Set 13 | umea
# Processing Record 46 of Set 13 | bani
# Processing Record 47 of Set 13 | himora
# City not found. Skipping...
# Processing Record 48 of Set 13 | lagos
# Processing Record 49 of Set 13 | lavrentiya
# Processing Record 50 of Set 13 | codrington
# Processing Record 1 of Set 14 | levelland
# Processing Record 2 of Set 14 | pitimbu
# Processing Record 3 of Set 14 | saint-joseph
# Processing Record 4 of Set 14 | ahipara
# Processing Record 5 of Set 14 | flin flon
# Processing Record 6 of Set 14 | san vicente
# Processing Record 7 of Set 14 | orotukan
# Processing Record 8 of Set 14 | srednekolymsk
# Processing Record 9 of Set 14 | hakvik
# City not found. Skipping...
# Processing Record 10 of Set 14 | kosh-agach
# Processing Record 11 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 14 | huarmey
# Processing Record 13 of Set 14 | corn island
# Processing Record 14 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 15 of Set 14 | mount vernon
# Processing Record 16 of Set 14 | karatuzskoye
# Processing Record 17 of Set 14 | farafenni
# Processing Record 18 of Set 14 | batticaloa
# Processing Record 19 of Set 14 | taunton
# Processing Record 20 of Set 14 | komarno
# Processing Record 21 of Set 14 | gweru
# Processing Record 22 of Set 14 | kazerun
# Processing Record 23 of Set 14 | gol
# Processing Record 24 of Set 14 | gore
# Processing Record 25 of Set 14 | west bay
# Processing Record 26 of Set 14 | kununurra
# Processing Record 27 of Set 14 | chernyshevskiy
# Processing Record 28 of Set 14 | cochrane
# Processing Record 29 of Set 14 | nueva loja
# Processing Record 30 of Set 14 | gimli
# Processing Record 31 of Set 14 | xinyu
# Processing Record 32 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 14 | corrales
# Processing Record 34 of Set 14 | pangkalanbuun
# Processing Record 35 of Set 14 | jinchang
# Processing Record 36 of Set 14 | boa vista
# Processing Record 37 of Set 14 | barcelona
# Processing Record 38 of Set 14 | murray bridge
# Processing Record 39 of Set 14 | harwich
# Processing Record 40 of Set 14 | hayden
# Processing Record 41 of Set 14 | cooma
# Processing Record 42 of Set 14 | svetlogorsk
# Processing Record 43 of Set 14 | batagay-alyta
# Processing Record 44 of Set 14 | jacareacanga
# Processing Record 45 of Set 14 | maceio
# Processing Record 46 of Set 14 | yenagoa
# Processing Record 47 of Set 14 | saint-georges
# Processing Record 48 of Set 14 | mogadishu
# Processing Record 49 of Set 14 | garhi khairo
# Processing Record 50 of Set 14 | ashland
# Processing Record 1 of Set 15 | hasaki
# Processing Record 2 of Set 15 | prince rupert
# Processing Record 3 of Set 15 | shcholkine
# City not found. Skipping...
# Processing Record 4 of Set 15 | ogaminana
# Processing Record 5 of Set 15 | werda
# Processing Record 6 of Set 15 | bom conselho
# Processing Record 7 of Set 15 | parrita
# Processing Record 8 of Set 15 | tarata
# Processing Record 9 of Set 15 | magadan
# Processing Record 10 of Set 15 | kokopo
# Processing Record 11 of Set 15 | zemio
# Processing Record 12 of Set 15 | buala
# Processing Record 13 of Set 15 | sistranda
# Processing Record 14 of Set 15 | mount isa
# Processing Record 15 of Set 15 | hallingby
# City not found. Skipping...
# Processing Record 16 of Set 15 | gat
# Processing Record 17 of Set 15 | wanlaweyn
# Processing Record 18 of Set 15 | opuwo
# Processing Record 19 of Set 15 | port-gentil
# Processing Record 20 of Set 15 | tuy hoa
# Processing Record 21 of Set 15 | san miguel
# Processing Record 22 of Set 15 | amiens
# Processing Record 23 of Set 15 | shimminato
# Processing Record 24 of Set 15 | taitung
# Processing Record 25 of Set 15 | nevelsk
# Processing Record 26 of Set 15 | harlingen
# Processing Record 27 of Set 15 | churapcha
# Processing Record 28 of Set 15 | lensk
# Processing Record 29 of Set 15 | ilabaya
# Processing Record 30 of Set 15 | moose factory
# Processing Record 31 of Set 15 | monze
# Processing Record 32 of Set 15 | la plata
# Processing Record 33 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 15 | mizan teferi
# Processing Record 35 of Set 15 | balkhash
# Processing Record 36 of Set 15 | svetlaya
# Processing Record 37 of Set 15 | korla
# Processing Record 38 of Set 15 | caraquet
# Processing Record 39 of Set 15 | durban
# Processing Record 40 of Set 15 | port lincoln
# Processing Record 41 of Set 15 | isangel
# Processing Record 42 of Set 15 | orlik
# Processing Record 43 of Set 15 | pangnirtung
# Processing Record 44 of Set 15 | bonao
# Processing Record 45 of Set 15 | high level
# Processing Record 46 of Set 15 | rorvik
# Processing Record 47 of Set 15 | skjervoy
# Processing Record 48 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 15 | novikovo
# Processing Record 50 of Set 15 | nantucket
# Processing Record 1 of Set 16 | wewak
# Processing Record 2 of Set 16 | turbiv
# Processing Record 3 of Set 16 | port hueneme
# Processing Record 4 of Set 16 | aripuana
# Processing Record 5 of Set 16 | pimentel
# Processing Record 6 of Set 16 | letlhakeng
# Processing Record 7 of Set 16 | susice
# Processing Record 8 of Set 16 | obo
# Processing Record 9 of Set 16 | luxor
# Processing Record 10 of Set 16 | cockburn town
# Processing Record 11 of Set 16 | zabid
# Processing Record 12 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 16 | alekseyevsk
# Processing Record 14 of Set 16 | nizhniy odes
# Processing Record 15 of Set 16 | roma
# Processing Record 16 of Set 16 | hirara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 717

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Puerto Ayacucho   5.6639  -67.6236     86.49        69          89
# 1          Koregaon  18.6500   74.0833     83.77        49          19
# 2            Broome  42.2506  -75.8330     75.38        68         100
# 3            Avarua -21.2078 -159.7750     80.69        81         100
# 4       Yellowknife  62.4560 -114.3525     46.56        59          18
# 5         Coihaique -45.5752  -72.0662     42.22        77          91
# 6       Clyde River  70.4692  -68.5914     25.45        63          21
# 7              Muli   2.9167   73.5667     81.95        80         100
# 8  Vega De Alatorre  20.0333  -96.6333     84.45        62          37
# 9              Hilo  19.7297 -155.0900     70.61        89          40
#
#    Wind Speed Country Current Description
# 0        3.87      VE     overcast clouds
# 1       16.73      IN          few clouds
# 2       10.36      US     overcast clouds
# 3       20.42      CK          light rain
# 4       10.40      CA          few clouds
# 5        9.46      CL     overcast clouds
# 6        6.78      CA          few clouds
# 7       15.26      MV       moderate rain
# 8        9.04      MX    scattered clouds
# 9        8.05      US       moderate rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0   Puerto Ayacucho      VE   5.6639  -67.6236     86.49        69
# 1          Koregaon      IN  18.6500   74.0833     83.77        49
# 2            Broome      US  42.2506  -75.8330     75.38        68
# 3            Avarua      CK -21.2078 -159.7750     80.69        81
# 4       Yellowknife      CA  62.4560 -114.3525     46.56        59
# 5         Coihaique      CL -45.5752  -72.0662     42.22        77
# 6       Clyde River      CA  70.4692  -68.5914     25.45        63
# 7              Muli      MV   2.9167   73.5667     81.95        80
# 8  Vega De Alatorre      MX  20.0333  -96.6333     84.45        62
# 9              Hilo      US  19.7297 -155.0900     70.61        89
#
#    Cloudiness  Wind Speed Current Description
# 0          89        3.87     overcast clouds
# 1          19       16.73          few clouds
# 2         100       10.36     overcast clouds
# 3         100       20.42          light rain
# 4          18       10.40          few clouds
# 5          91        9.46     overcast clouds
# 6          21        6.78          few clouds
# 7         100       15.26       moderate rain
# 8          37        9.04    scattered clouds
# 9          40        8.05       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
